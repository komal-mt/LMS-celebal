# %% [markdown]
# ## 1.Dealing with missing values

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("AB_NYC_2019.csv")
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
a = df.copy()

# %%
a.dropna(inplace= True)
a.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %% [markdown]
# ## 2.Fill the missing values using imputation

# %%
b= df.copy()

# %%
b.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
mean = b["reviews_per_month"].mean()

# %%
mean = np.round(mean,2)
mean
# Out:
# 1.37

# %%
b["reviews_per_month"] = b["reviews_per_month"].fillna(mean)

# %%
b.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# ## 3.Fill the categorical data - col[last_review]

# %%
b.nunique()
# Out:
# id                                48895
# name                              47896
# host_id                           37457
# host_name                         11452
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %%
mode = b["last_review"].value_counts().index[0]   # it genrates the mode we can also use mode function but it is not cool
mode
# Out:
# '23-06-2019'

# %%
b["last_review"] = b["last_review"].fillna(mode)

# %%
b.isnull().sum()
# Out:
# id                                 0
# name                              16
# host_id                            0
# host_name                         21
# neighbourhood_group                0
# neighbourhood                      0
# latitude                           0
# longitude                          0
# room_type                          0
# price                              0
# minimum_nights                     0
# number_of_reviews                  0
# last_review                        0
# reviews_per_month                  0
# calculated_host_listings_count     0
# availability_365                   0
# dtype: int64

# %% [markdown]
# ## 4.Advance Imputation

# %%
c = df.copy()

# %%
c["reviews_per_month"].interpolate(inplace = True) # the interpolate function took upper and lower value to the missing value
c.head()                                           #    and made a mean of two values inplace of missing value.
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10884\2248430853.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   c["reviews_per_month"].interpolate(inplace = True) # the interpolate function took upper and lower value to the missing value
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# ...

# %%
#  interpolate is not a good function for the missing values becaues it depends upon a very two value which can effect
#      our dataset pridiction badly

# %%
df.duplicated().sum()
# Out:
# 11

# %%
df[df.duplicated(keep = False)] # keep = False means it canm provde all duplicated values in a dataset
# Out:
#          id                                              name  host_id  \
# 5      5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6      5121                                   BlissArtsSpace!     7356
# 7      5178                  Large Furnished Room Near B'way      8967
# 8      5203                Cozy Clean Guest Room - Family Apt     7490
# 9      5238                Cute & Cozy Lower East Side 1 bdrm     7549
# 10     5295                  Beautiful 1br on Upper West Side     7702
# 11     5441                   Central Manhattan/near Broadway     7989
# 12     5803    Lovely Room 1, Garden, Best Area, Legal rental     9744
# 13     6021  Wonderful Guest Bedroom in Manhattan for SINGLES    11528
# 14     6090                     West Village Nest - Superhost    11975
# 15     6848                  Only 2 stops to Manhattan studio    15991
# 48895  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# ...

# %%
df[df.duplicated(keep = "first")]  # this will gave last duplicated values that came in a datata set
# Out:
#          id                                              name  host_id  \
# 48895  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 48896  5121                                   BlissArtsSpace!     7356
# 48897  5178                  Large Furnished Room Near B'way      8967
# 48898  5203                Cozy Clean Guest Room - Family Apt     7490
# 48899  5238                Cute & Cozy Lower East Side 1 bdrm     7549
# 48900  5295                  Beautiful 1br on Upper West Side     7702
# 48901  5441                   Central Manhattan/near Broadway     7989
# 48902  5803    Lovely Room 1, Garden, Best Area, Legal rental     9744
# 48903  6021  Wonderful Guest Bedroom in Manhattan for SINGLES    11528
# 48904  6090                     West Village Nest - Superhost    11975
# 48905  6848                  Only 2 stops to Manhattan studio    15991
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# ...

# %% [markdown]
# ## 2.Drop duplicated values

# %%
a= df.copy()

# %%
a.drop_duplicates(keep = False)
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
cities = ["new york" , "la" , "chicago" , "houston" , "pheonix" , "la" , "chicago"]
rankings = [1,2,3,4,5,6,7]
scores = [9.8,8.8,8.5,8.2,7.7,7.4,7.3]
data = {"city" : cities , "ranks" : rankings, "score" : scores}

m = pd.DataFrame(data)
m
# Out:
#        city  ranks  score
# 0  new york      1    9.8
# 1        la      2    8.8
# 2   chicago      3    8.5
# 3   houston      4    8.2
# 4   pheonix      5    7.7
# 5        la      6    7.4
# 6   chicago      7    7.3

# %%
m["city"].drop_duplicates(keep="first")
# Out:
# 0    new york
# 1          la
# 2     chicago
# 3     houston
# 4     pheonix
# Name: city, dtype: object

# %%
m["city"].drop_duplicates(keep="last")
# Out:
# 0    new york
# 3     houston
# 4     pheonix
# 5          la
# 6     chicago
# Name: city, dtype: object

# %%
m["city"].drop_duplicates(keep = False)
# Out:
# 0    new york
# 3     houston
# 4     pheonix
# Name: city, dtype: object

# %%
import seaborn as sns

# %%
sns.countplot(df , x="neighbourhood_group")
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='count'>

# %%
sns.countplot(df , x= "room_type" )
# Out:
# <Axes: xlabel='room_type', ylabel='count'>

# %%
sns.countplot(df , x="neighbourhood_group",hue = "room_type")
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='count'>

# %% [markdown]
# ### Pie chart

# %%
df["room_type"].value_counts().plot(kind = "pie",autopct = "%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
sns.histplot(df[df["price"] < 500], x = "price") # hist plot
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.displot(df , x="price",kde = True)  # dis plot tell us obout distributions on the data

# %%
sns.displot(df , x= "reviews_per_month",kde = True)

# %% [markdown]
# ## box plot

# %%
sns.boxplot(df , y=  "price")
# Out:
# <Axes: ylabel='price'>

# %% [markdown]
# ## Outliers Removal

# %%
sns.boxplot(df[df["price"] < 500] , y=  "price") # box plot after removing outliers
# Out:
# <Axes: ylabel='price'>
